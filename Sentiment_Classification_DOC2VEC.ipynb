# %%
# %matplotlib inline

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# Introduction
# ------------
# steps:
#
# #. Load the IMDB dataset
# #. Train a variety of Doc2Vec models on the dataset
# #. Evaluate the performance of each model using a logistic regression
# #. Examine some of the results directly:
#
# When examining results, we will look for answers for the following questions:
#
# #. Are inferred vectors close to the precalculated ones?
# #. Do close documents seem more related than distant ones?
# #. Do the word vectors show useful similarities?
# #. Are the word vectors from this dataset any good at analogies?
#
# Load corpus
# -----------
#
# data is available on `IMDB archive
# <http://ai.stanford.edu/~amaas/data/sentiment/>`_.
#
# Each review is a single line of text containing multiple sentences, for example:
#
# ```
# One of the best movie-dramas I have ever seen. We do a lot of acting in the
# church and this is one that can be used as a resource that highlights all the
# good things that actors can do in their work. I highly recommend this one,
# especially for those who have an interest in acting, as a "must see."
# ```
#
# These reviews will be the **documents** that we will work with in this tutorial.
# There are 100 thousand reviews in total.
#
# #. 25k reviews for training (12.5k positive, 12.5k negative)
# #. 25k reviews for testing (12.5k positive, 12.5k negative)
# #. 50k unlabeled reviews
#
# Out of 100k reviews, 50k have a label: either positive (the reviewer liked
# the movie) or negative.
# The remaining 50k are unlabeled.
#
#
# #. Download the tar.gz file (it's only 84MB, so this shouldn't take too long)
# #. Unpack it and extract each movie review
# #. Split the reviews into training and test datasets
#
# define a convenient datatype for holding data for a single document:
#
# * words: The text of the document, as a ``list`` of words.
# * tags: Used to keep the index of the document in the entire dataset.
# * split: one of ``train``\ , ``test`` or ``extra``. Determines how the document will be used (for training, testing, etc).
# * sentiment: either 1 (positive), 0 (negative) or None (unlabeled document).
#
# This data type is helpful for later evaluation and reporting.
# In particular, the ``index`` member will help us quickly and easily retrieve the vectors for a document from a model.

# %%
import collections

SentimentDocument = collections.namedtuple('SentimentDocument', 'words tags split sentiment')

# %%
! pip install gensim
# Out:
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/09/ed/b59a2edde05b7f5755ea68648487c150c7c742361e9c8733c6d4ca005020/gensim-3.8.1-cp37-cp37m-win_amd64.whl (24.2MB)
# Requirement already satisfied: six>=1.5.0 in c:\users\revanth\anaconda3\lib\site-packages (from gensim) (1.12.0)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\revanth\anaconda3\lib\site-packages (from gensim) (1.16.2)
# Requirement already satisfied: scipy>=0.18.1 in c:\users\revanth\anaconda3\lib\site-packages (from gensim) (1.1.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\revanth\anaconda3\lib\site-packages (from gensim) (1.9.0)
# Requirement already satisfied: requests in c:\users\revanth\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.19.1)
# Requirement already satisfied: boto3 in c:\users\revanth\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (1.10.23)
# Requirement already satisfied: boto>=2.32 in c:\users\revanth\anaconda3\lib\site-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\revanth\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\revanth\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in c:\users\revanth\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (2.7)
# Requirement already satisfied: urllib3<1.24,>=1.21.1 in c:\users\revanth\anaconda3\lib\site-packages (from requests->smart-open>=1.8.1->gensim) (1.23)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in c:\users\revanth\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.2.1)
# Requirement already satisfied: botocore<1.14.0,>=1.13.23 in c:\users\revanth\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (1.13.23)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\revanth\anaconda3\lib\site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.4)
# Requirement already satisfied: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in c:\users\revanth\anaconda3\lib\site-packages (from botocore<1.14.0,>=1.13.23->boto3->smart-open>=1.8.1->gensim) (2.7.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in c:\users\revanth\anaconda3\lib\site-packages (from botocore<1.14.0,>=1.13.23->boto3->smart-open>=1.8.1->gensim) (0.14)
# Installing collected packages: gensim
# Successfully installed gensim-3.8.1

# %% [markdown]
# We can now proceed with loading the corpus.

# %%
import io
import re
import tarfile
import os.path

import smart_open
import gensim.utils

def download_dataset(url='http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz'):
    fname = url.split('/')[-1]

    if os.path.isfile(fname):
       return fname

    # Download the file to local storage first.
    # We can't read it on the fly because of
    # https://github.com/RaRe-Technologies/smart_open/issues/331
    with smart_open.open(url, "rb", ignore_ext=True) as fin:
        with smart_open.open(fname, 'wb', ignore_ext=True) as fout:
            while True:
                buf = fin.read(io.DEFAULT_BUFFER_SIZE)
                if not buf:
                    break
                fout.write(buf)

    return fname

def create_sentiment_document(name, text, index):
    _, split, sentiment_str, _ = name.split('/')
    sentiment = {'pos': 1.0, 'neg': 0.0, 'unsup': None}[sentiment_str]

    if sentiment is None:
        split = 'extra'

    tokens = gensim.utils.to_unicode(text).split()
    return SentimentDocument(tokens, [index], split, sentiment)

def extract_documents():
    fname = download_dataset()

    index = 0

    with tarfile.open(fname, mode='r:gz') as tar:
        for member in tar.getmembers():
            if re.match(r'aclImdb/(train|test)/(pos|neg|unsup)/\d+_\d+.txt$', member.name):
                member_bytes = tar.extractfile(member).read()
                member_text = member_bytes.decode('utf-8', errors='replace')
                assert member_text.count('\n') == 0
                yield create_sentiment_document(member.name, member_text, index)
                index += 1

alldocs = list(extract_documents())

# %% [markdown]
# Here's what a single document looks like

# %%
print(alldocs[27])
# Out:
# SentimentDocument(words=['I', 'was', 'looking', 'forward', 'to', 'this', 'movie.', 'Trustworthy', 'actors,', 'interesting', 'plot.', 'Great', 'atmosphere', 'then', '?????', 'IF', 'you', 'are', 'going', 'to', 'attempt', 'something', 'that', 'is', 'meant', 'to', 'encapsulate', 'the', 'meaning', 'of', 'life.', 'First.', 'Know', 'it.', 'OK', 'I', 'did', 'not', 'expect', 'the', 'directors', 'or', 'writers', 'to', 'actually', 'know', 'the', 'meaning', 'but', 'I', 'thought', 'they', 'may', 'have', 'offered', 'crumbs', 'to', 'peck', 'at', 'and', 'treats', 'to', 'add', 'fuel', 'to', 'the', 'fire-Which!', 'they', 'almost', 'did.', 'Things', 'I', "didn't", 'get.', 'A', 'woman', 'wandering', 'around', 'in', 'dark', 'places', 'and', 'lonely', 'car', 'parks', 'alone-oblivious', 'to', 'the', 'consequences.', 'Great', 'riddles', 'that', 'fell', 'by', 'the', 'wayside.', 'The', 'promise', 'of', 'the', 'knowledge', 'therein', 'contained', 'by', 'the', 'original', 'so-called', 'criminal.', 'I', 'had', 'no', 'problem', 'with', 'the', 'budget', 'and', 'enjoyed', 'the', 'suspense.', 'I', 'understood', 'and', 'can', 'wax', 'lyrical', 'about', 'the', 'fool', 'and', 'found', 'Adrian', 'Pauls', 'role', 'crucial', 'and', 'penetrating', 'and', 'then', '?????', 'Basically', 'the', 'story', 'line', 'and', 'the', 'script', 'where', 'good', 'up', 'to', 'a', 'point', 'and', 'that', 'point', 'was', 'the', 'last', '10', 'minutes', 'or', 'so.', 'What?', 'Run', 'out', 'of', 'ideas!', 'Such', 'a', 'pity', 'that', 'this', 'movie', 'had', 'to', 'let', 'us', 'down', 'so', 'badly.', 'It', 'may', 'not', 'comprehend', 'the', 'meaning', 'and', 'I', 'really', 'did', 'not', 'expect', 'the', 'writers', 'to', 'understand', 'it', 'but', 'I', 'was', 'hoping', 'for', 'an', 'intellectual,', 'if', 'not', 'spiritual', 'ride', 'and', 'got', 'a', 'bump', 'in', 'the', 'road'], tags=[27], split='test', sentiment=0.0)

# %% [markdown]
# Extract our documents and split into training/test sets

# %%
train_docs = [doc for doc in alldocs if doc.split == 'train']
test_docs = [doc for doc in alldocs if doc.split == 'test']
print('%d docs: %d train-sentiment, %d test-sentiment' % (len(alldocs), len(train_docs), len(test_docs)))
# Out:
# 100000 docs: 25000 train-sentiment, 25000 test-sentiment

# %% [markdown]
# Set-up Doc2Vec Training & Evaluation Models
# -------------------------------------------
#
#
# We vary the following parameter choices:
#
# * 100-dimensional vectors, as the 400-d vectors of the paper take a lot of
#   memory and, in our tests of this task, don't seem to offer much benefit
# * Similarly, frequent word subsampling seems to decrease sentiment-prediction
#   accuracy, so it's left out
# * ``cbow=0`` means skip-gram which is equivalent to the paper's 'PV-DBOW'
#   mode, matched in gensim with ``dm=0``
# * Added to that DBOW model are two DM models, one which averages context
#   vectors (\ ``dm_mean``\ ) and one which concatenates them (\ ``dm_concat``\ ,
#   resulting in a much larger, slower, more data-hungry model)
# * A ``min_count=2`` saves quite a bit of model memory, discarding only words
#   that appear in a single doc (and are thus no more expressive than the
#   unique-to-each doc vectors themselves)

# %%
import multiprocessing
from collections import OrderedDict

import gensim.models.doc2vec
assert gensim.models.doc2vec.FAST_VERSION > -1, "This will be painfully slow otherwise"

from gensim.models.doc2vec import Doc2Vec

common_kwargs = dict(
    vector_size=100, epochs=20, min_count=2,
    sample=0, workers=multiprocessing.cpu_count(), negative=5, hs=0,
)

simple_models = [
    # PV-DBOW plain
    Doc2Vec(dm=0, **common_kwargs),
    # PV-DM w/ default averaging; a higher starting alpha may improve CBOW/PV-DM modes
    Doc2Vec(dm=1, window=10, alpha=0.05, comment='alpha=0.05', **common_kwargs),
    # PV-DM w/ concatenation - big, slow, experimental mode
    # window=5 (both sides) approximates paper's apparent 10-word total window size
    Doc2Vec(dm=1, dm_concat=1, window=5, **common_kwargs),
]

for model in simple_models:
    model.build_vocab(alldocs)
    print("%s vocabulary scanned & state initialized" % model)

models_by_name = OrderedDict((str(model), model) for model in simple_models)
# Out:
# 2019-11-21 17:03:27,612 : INFO : using concatenative 1100-dimensional layer1
# 2019-11-21 17:03:27,614 : INFO : collecting all words and their counts
# 2019-11-21 17:03:27,615 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2019-11-21 17:03:28,227 : INFO : PROGRESS: at example #10000, processed 2292381 words (3747805/s), 150816 word types, 10000 tags
# 2019-11-21 17:03:28,804 : INFO : PROGRESS: at example #20000, processed 4573645 words (3955736/s), 238497 word types, 20000 tags
# 2019-11-21 17:03:29,424 : INFO : PROGRESS: at example #30000, processed 6865575 words (3706859/s), 312348 word types, 30000 tags
# 2019-11-21 17:03:30,056 : INFO : PROGRESS: at example #40000, processed 9190019 words (3683341/s), 377231 word types, 40000 tags
# 2019-11-21 17:03:30,713 : INFO : PROGRESS: at example #50000, processed 11557847 words (3606381/s), 438729 word types, 50000 tags
# 2019-11-21 17:03:31,335 : INFO : PROGRESS: at example #60000, processed 13899883 words (3772862/s), 493913 word types, 60000 tags
# 2019-11-21 17:03:31,950 : INFO : PROGRESS: at example #70000, processed 16270094 words (3858956/s), 548474 word types, 70000 tags
# 2019-11-21 17:03:32,584 : INFO : PROGRESS: at example #80000, processed 18598876 words (3676453/s), 598272 word types, 80000 tags
# 2019-11-21 17:03:33,180 : INFO : PROGRESS: at example #90000, processed 20916044 words (3896251/s), 646082 word types, 90000 tags
# 2019-11-21 17:03:33,830 : INFO : collected 693922 word types and 100000 unique tags from a corpus of 100000 examples and 23279529 words
# 2019-11-21 17:03:33,831 : INFO : Loading a fresh vocabulary
# 2019-11-21 17:03:35,210 : INFO : effective_min_count=2 retains 265408 unique words (38% of original 693922, drops 428514)
# 2019-11-21 17:03:35,211 : INFO : effective_min_count=2 leaves 22851015 word corpus (98% of original 23279529, drops 428514)
# 2019-11-21 17:03:35,998 : INFO : deleting the raw counts dictionary of 693922 items
# 2019-11-21 17:03:36,012 : INFO : sample=0 downsamples 0 most-common words
# 2019-11-21 17:03:36,013 : INFO : downsampling leaves estimated 22851015 word corpus (100.0% of prior 22851015)
# 2019-11-21 17:03:36,995 : INFO : estimated required memory for 265408 words and 100 dimensions: 385030400 bytes
# 2019-11-21 17:03:36,996 : INFO : resetting layer weights
# 2019-11-21 17:03:42,080 : INFO : collecting all words and their counts
# 2019-11-21 17:03:42,080 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# Doc2Vec(dbow,d100,n5,mc2,t4) vocabulary scanned & state initialized
# 2019-11-21 17:03:42,664 : INFO : PROGRESS: at example #10000, processed 2292381 words (3938447/s), 150816 word types, 10000 tags
# 2019-11-21 17:03:43,176 : INFO : PROGRESS: at example #20000, processed 4573645 words (4468265/s), 238497 word types, 20000 tags
# 2019-11-21 17:03:43,754 : INFO : PROGRESS: at example #30000, processed 6865575 words (3965285/s), 312348 word types, 30000 tags
# 2019-11-21 17:03:44,336 : INFO : PROGRESS: at example #40000, processed 9190019 words (4007503/s), 377231 word types, 40000 tags
# 2019-11-21 17:03:44,922 : INFO : PROGRESS: at example #50000, processed 11557847 words (4038083/s), 438729 word types, 50000 tags
# 2019-11-21 17:03:45,478 : INFO : PROGRESS: at example #60000, processed 13899883 words (4235782/s), 493913 word types, 60000 tags
# 2019-11-21 17:03:46,086 : INFO : PROGRESS: at example #70000, processed 16270094 words (3898611/s), 548474 word types, 70000 tags
# 2019-11-21 17:03:46,650 : INFO : PROGRESS: at example #80000, processed 18598876 words (4141055/s), 598272 word types, 80000 tags
# 2019-11-21 17:03:47,232 : INFO : PROGRESS: at example #90000, processed 20916044 words (3983432/s), 646082 word types, 90000 tags
# 2019-11-21 17:03:47,986 : INFO : collected 693922 word types and 100000 unique tags from a corpus of 100000 examples and 23279529 words
# 2019-11-21 17:03:47,988 : INFO : Loading a fresh vocabulary
# 2019-11-21 17:03:49,558 : INFO : effective_min_count=2 retains 265408 unique words (38% of original 693922, drops 428514)
# 2019-11-21 17:03:49,559 : INFO : effective_min_count=2 leaves 22851015 word corpus (98% of original 23279529, drops 428514)
# 2019-11-21 17:03:50,338 : INFO : deleting the raw counts dictionary of 693922 items
# 2019-11-21 17:03:50,351 : INFO : sample=0 downsamples 0 most-common words
# 2019-11-21 17:03:50,352 : INFO : downsampling leaves estimated 22851015 word corpus (100.0% of prior 22851015)
# 2019-11-21 17:03:51,331 : INFO : estimated required memory for 265408 words and 100 dimensions: 385030400 bytes
# 2019-11-21 17:03:51,333 : INFO : resetting layer weights
# 2019-11-21 17:03:56,643 : INFO : collecting all words and their counts
# 2019-11-21 17:03:56,644 : INFO : PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t4) vocabulary scanned & state initialized
# 2019-11-21 17:03:57,185 : INFO : PROGRESS: at example #10000, processed 2292381 words (4246788/s), 150816 word types, 10000 tags
# 2019-11-21 17:03:57,732 : INFO : PROGRESS: at example #20000, processed 4573645 words (4180321/s), 238497 word types, 20000 tags
# 2019-11-21 17:03:58,263 : INFO : PROGRESS: at example #30000, processed 6865575 words (4331546/s), 312348 word types, 30000 tags
# 2019-11-21 17:03:58,850 : INFO : PROGRESS: at example #40000, processed 9190019 words (3964787/s), 377231 word types, 40000 tags
# 2019-11-21 17:03:59,427 : INFO : PROGRESS: at example #50000, processed 11557847 words (4113837/s), 438729 word types, 50000 tags
# 2019-11-21 17:03:59,972 : INFO : PROGRESS: at example #60000, processed 13899883 words (4311051/s), 493913 word types, 60000 tags
# 2019-11-21 17:04:00,588 : INFO : PROGRESS: at example #70000, processed 16270094 words (3856949/s), 548474 word types, 70000 tags
# 2019-11-21 17:04:01,136 : INFO : PROGRESS: at example #80000, processed 18598876 words (4262274/s), 598272 word types, 80000 tags
# 2019-11-21 17:04:01,713 : INFO : PROGRESS: at example #90000, processed 20916044 words (4020741/s), 646082 word types, 90000 tags
# 2019-11-21 17:04:02,311 : INFO : collected 693922 word types and 100000 unique tags from a corpus of 100000 examples and 23279529 words
# 2019-11-21 17:04:02,312 : INFO : Loading a fresh vocabulary
# 2019-11-21 17:04:03,635 : INFO : effective_min_count=2 retains 265408 unique words (38% of original 693922, drops 428514)
# 2019-11-21 17:04:03,636 : INFO : effective_min_count=2 leaves 22851015 word corpus (98% of original 23279529, drops 428514)
# 2019-11-21 17:04:04,407 : INFO : deleting the raw counts dictionary of 693922 items
# 2019-11-21 17:04:04,421 : INFO : sample=0 downsamples 0 most-common words
# 2019-11-21 17:04:04,422 : INFO : downsampling leaves estimated 22851015 word corpus (100.0% of prior 22851015)
# 2019-11-21 17:04:05,347 : INFO : estimated required memory for 265408 words and 100 dimensions: 1446662400 bytes
# 2019-11-21 17:04:05,348 : INFO : resetting layer weights
# Doc2Vec(dm/c,d100,n5,w5,mc2,t4) vocabulary scanned & state initialized

# %% [markdown]
# Le and Mikolov note that combining a paragraph vector from Distributed Bag of
# Words (DBOW) and Distributed Memory (DM) improves performance. We will
# follow, pairing the models together for evaluation. Here, we concatenate the
# paragraph vectors obtained from each model with the help of a thin wrapper
# class included in a gensim test module.

# %%
# !pip install testfixtures
# Out:
# Collecting testfixtures
#   Downloading https://files.pythonhosted.org/packages/6a/fe/0cf62bbb32c3589e955a447d582c9d07b051baf5edc3fae9973709766353/testfixtures-6.10.2-py2.py3-none-any.whl (86kB)
# Installing collected packages: testfixtures
# Successfully installed testfixtures-6.10.2

# %%
from gensim.test.test_doc2vec import ConcatenatedDoc2Vec
models_by_name['dbow+dmm'] = ConcatenatedDoc2Vec([simple_models[0], simple_models[1]])
models_by_name['dbow+dmc'] = ConcatenatedDoc2Vec([simple_models[0], simple_models[2]])
# Out:
# 2019-11-21 17:06:36,529 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-11-21 17:06:36,534 : INFO : built Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...) from 9 documents (total 29 corpus positions)

# %% [markdown]
# Predictive Evaluation Methods
# -----------------------------
#
# Given a document, our ``Doc2Vec`` models output a vector representation of the document.
# How useful is a particular model?
# In case of sentiment analysis, we want the ouput vector to reflect the sentiment in the input document.
# So, in vector space, positive documents should be distant from negative documents.
#
# We train a logistic regression from the training set:
#
#   - regressors (inputs): document vectors from the Doc2Vec model
#   - target (outpus): sentiment labels
#
# So, this logistic regression will be able to predict sentiment given a document vector.
#
# Next, we test our logistic regression on the test set, and measure the rate of errors (incorrect predictions).
# If the document vectors from the Doc2Vec model reflect the actual sentiment well, the error rate will be low.
#
# Therefore, the error rate of the logistic regression is indication of *how well* the given Doc2Vec model represents documents as vectors.
# We can then compare different ``Doc2Vec`` models by looking at their error rates.

# %%
import numpy as np
import statsmodels.api as sm
from random import sample

def logistic_predictor_from_data(train_targets, train_regressors):
    """Fit a statsmodel logistic predictor on supplied data"""
    logit = sm.Logit(train_targets, train_regressors)
    predictor = logit.fit(disp=0)
    # print(predictor.summary())
    return predictor

def error_rate_for_model(test_model, train_set, test_set):
    """Report error rate on test_doc sentiments, using supplied model and train_docs"""

    train_targets = [doc.sentiment for doc in train_set]
    train_regressors = [test_model.docvecs[doc.tags[0]] for doc in train_set]
    train_regressors = sm.add_constant(train_regressors)
    predictor = logistic_predictor_from_data(train_targets, train_regressors)

    test_regressors = [test_model.docvecs[doc.tags[0]] for doc in test_set]
    test_regressors = sm.add_constant(test_regressors)

    # Predict & evaluate
    test_predictions = predictor.predict(test_regressors)
    corrects = sum(np.rint(test_predictions) == [doc.sentiment for doc in test_set])
    errors = len(test_predictions) - corrects
    error_rate = float(errors) / len(test_predictions)
    return (error_rate, errors, len(test_predictions), predictor)

# %% [markdown]
# Bulk Training & Per-Model Evaluation
# ------------------------------------
#
# Note that doc-vector training is occurring on *all* documents of the dataset,
# which includes all TRAIN/TEST/DEV docs.  Because the native document-order
# has similar-sentiment documents in large clumps – which is suboptimal for
# training – we work with once-shuffled copy of the training set.
#
# We evaluate each model's sentiment predictive power based on error rate, and
# the evaluation is done for each model.

# %%
from collections import defaultdict
error_rates = defaultdict(lambda: 1.0)  # To selectively print only best errors achieved

# %%
from random import shuffle
shuffled_alldocs = alldocs[:]
shuffle(shuffled_alldocs)

for model in simple_models:
    print("Training %s" % model)
    model.train(shuffled_alldocs, total_examples=len(shuffled_alldocs), epochs=model.epochs)

    print("\nEvaluating %s" % model)
    err_rate, err_count, test_count, predictor = error_rate_for_model(model, train_docs, test_docs)
    error_rates[str(model)] = err_rate
    print("\n%f %s\n" % (err_rate, model))

for model in [models_by_name['dbow+dmm'], models_by_name['dbow+dmc']]:
    print("\nEvaluating %s" % model)
    err_rate, err_count, test_count, predictor = error_rate_for_model(model, train_docs, test_docs)
    error_rates[str(model)] = err_rate
    print("\n%f %s\n" % (err_rate, model))
# Out:
# 2019-11-21 17:07:00,563 : INFO : training model with 4 workers on 265408 vocabulary and 100 features, using sg=1 hs=0 sample=0 negative=5 window=5
# Training Doc2Vec(dbow,d100,n5,mc2,t4)
# 2019-11-21 17:07:01,601 : INFO : EPOCH 1 - PROGRESS: at 3.88% examples, 900425 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:02,609 : INFO : EPOCH 1 - PROGRESS: at 8.43% examples, 977406 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:03,618 : INFO : EPOCH 1 - PROGRESS: at 13.14% examples, 1007538 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:04,618 : INFO : EPOCH 1 - PROGRESS: at 17.90% examples, 1026540 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:05,619 : INFO : EPOCH 1 - PROGRESS: at 22.69% examples, 1037116 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:06,620 : INFO : EPOCH 1 - PROGRESS: at 27.28% examples, 1040022 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:07,623 : INFO : EPOCH 1 - PROGRESS: at 32.04% examples, 1044958 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:08,623 : INFO : EPOCH 1 - PROGRESS: at 36.58% examples, 1048531 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:09,626 : INFO : EPOCH 1 - PROGRESS: at 40.78% examples, 1038293 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:10,628 : INFO : EPOCH 1 - PROGRESS: at 44.76% examples, 1025424 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:11,629 : INFO : EPOCH 1 - PROGRESS: at 49.09% examples, 1022766 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:12,632 : INFO : EPOCH 1 - PROGRESS: at 53.87% examples, 1029276 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:13,650 : INFO : EPOCH 1 - PROGRESS: at 58.53% examples, 1031544 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:14,663 : INFO : EPOCH 1 - PROGRESS: at 63.15% examples, 1032964 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:15,676 : INFO : EPOCH 1 - PROGRESS: at 67.81% examples, 1033946 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:16,677 : INFO : EPOCH 1 - PROGRESS: at 72.54% examples, 1036551 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:17,679 : INFO : EPOCH 1 - PROGRESS: at 77.08% examples, 1035512 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:18,692 : INFO : EPOCH 1 - PROGRESS: at 81.04% examples, 1027948 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:19,696 : INFO : EPOCH 1 - PROGRESS: at 84.78% examples, 1018887 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:20,713 : INFO : EPOCH 1 - PROGRESS: at 89.45% examples, 1021310 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:21,719 : INFO : EPOCH 1 - PROGRESS: at 94.23% examples, 1023943 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:22,723 : INFO : EPOCH 1 - PROGRESS: at 98.91% examples, 1026097 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:22,929 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:07:22,937 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:07:22,945 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:07:22,956 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:07:22,957 : INFO : EPOCH - 1 : training on 23279529 raw words (22951015 effective words) took 22.4s, 1026551 effective words/s
# 2019-11-21 17:07:23,976 : INFO : EPOCH 2 - PROGRESS: at 4.49% examples, 1022512 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:24,984 : INFO : EPOCH 2 - PROGRESS: at 9.16% examples, 1056979 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:25,985 : INFO : EPOCH 2 - PROGRESS: at 13.89% examples, 1063164 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:26,986 : INFO : EPOCH 2 - PROGRESS: at 18.65% examples, 1065548 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:27,989 : INFO : EPOCH 2 - PROGRESS: at 23.43% examples, 1070081 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:29,017 : INFO : EPOCH 2 - PROGRESS: at 28.21% examples, 1067564 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 17:07:30,037 : INFO : EPOCH 2 - PROGRESS: at 33.00% examples, 1068702 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:31,041 : INFO : EPOCH 2 - PROGRESS: at 37.67% examples, 1072385 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:32,059 : INFO : EPOCH 2 - PROGRESS: at 42.57% examples, 1074967 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:33,065 : INFO : EPOCH 2 - PROGRESS: at 47.28% examples, 1076250 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:34,080 : INFO : EPOCH 2 - PROGRESS: at 52.02% examples, 1075487 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:35,083 : INFO : EPOCH 2 - PROGRESS: at 56.75% examples, 1076462 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:36,085 : INFO : EPOCH 2 - PROGRESS: at 61.39% examples, 1076076 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:37,089 : INFO : EPOCH 2 - PROGRESS: at 66.14% examples, 1076176 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:38,097 : INFO : EPOCH 2 - PROGRESS: at 70.89% examples, 1076034 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:39,100 : INFO : EPOCH 2 - PROGRESS: at 75.55% examples, 1074241 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:40,115 : INFO : EPOCH 2 - PROGRESS: at 79.46% examples, 1063290 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:41,127 : INFO : EPOCH 2 - PROGRESS: at 83.65% examples, 1056196 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:42,145 : INFO : EPOCH 2 - PROGRESS: at 88.30% examples, 1057167 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:43,145 : INFO : EPOCH 2 - PROGRESS: at 93.09% examples, 1058432 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:44,153 : INFO : EPOCH 2 - PROGRESS: at 97.68% examples, 1058413 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:44,611 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:07:44,612 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:07:44,612 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:07:44,613 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:07:44,614 : INFO : EPOCH - 2 : training on 23279529 raw words (22951015 effective words) took 21.7s, 1059985 effective words/s
# 2019-11-21 17:07:45,628 : INFO : EPOCH 3 - PROGRESS: at 4.49% examples, 1027612 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:46,629 : INFO : EPOCH 3 - PROGRESS: at 8.87% examples, 1030066 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:47,634 : INFO : EPOCH 3 - PROGRESS: at 13.27% examples, 1017944 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:48,637 : INFO : EPOCH 3 - PROGRESS: at 17.78% examples, 1019166 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:49,644 : INFO : EPOCH 3 - PROGRESS: at 22.26% examples, 1016802 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:50,647 : INFO : EPOCH 3 - PROGRESS: at 26.64% examples, 1014548 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:07:51,649 : INFO : EPOCH 3 - PROGRESS: at 29.89% examples, 974953 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:52,678 : INFO : EPOCH 3 - PROGRESS: at 33.49% examples, 952760 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:53,687 : INFO : EPOCH 3 - PROGRESS: at 36.12% examples, 915078 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:54,695 : INFO : EPOCH 3 - PROGRESS: at 39.68% examples, 906072 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:55,714 : INFO : EPOCH 3 - PROGRESS: at 43.23% examples, 895366 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:56,724 : INFO : EPOCH 3 - PROGRESS: at 47.36% examples, 899910 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:57,726 : INFO : EPOCH 3 - PROGRESS: at 51.72% examples, 907277 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:58,731 : INFO : EPOCH 3 - PROGRESS: at 55.55% examples, 905534 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:07:59,747 : INFO : EPOCH 3 - PROGRESS: at 59.56% examples, 905868 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:00,751 : INFO : EPOCH 3 - PROGRESS: at 63.32% examples, 902848 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:01,780 : INFO : EPOCH 3 - PROGRESS: at 66.90% examples, 895992 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:02,782 : INFO : EPOCH 3 - PROGRESS: at 70.82% examples, 895620 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:03,786 : INFO : EPOCH 3 - PROGRESS: at 74.83% examples, 896346 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:04,821 : INFO : EPOCH 3 - PROGRESS: at 79.33% examples, 901370 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:05,833 : INFO : EPOCH 3 - PROGRESS: at 83.91% examples, 907163 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:08:06,836 : INFO : EPOCH 3 - PROGRESS: at 86.74% examples, 896661 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:07,849 : INFO : EPOCH 3 - PROGRESS: at 91.04% examples, 899556 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:08,852 : INFO : EPOCH 3 - PROGRESS: at 95.22% examples, 901582 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:09,881 : INFO : EPOCH 3 - PROGRESS: at 98.99% examples, 899400 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:10,129 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:08:10,138 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:08:10,142 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:08:10,147 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:08:10,150 : INFO : EPOCH - 3 : training on 23279529 raw words (22951015 effective words) took 25.5s, 898960 effective words/s
# 2019-11-21 17:08:11,178 : INFO : EPOCH 4 - PROGRESS: at 3.42% examples, 778675 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:12,191 : INFO : EPOCH 4 - PROGRESS: at 7.53% examples, 862067 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:08:13,222 : INFO : EPOCH 4 - PROGRESS: at 10.55% examples, 799252 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:14,225 : INFO : EPOCH 4 - PROGRESS: at 13.52% examples, 768827 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:15,225 : INFO : EPOCH 4 - PROGRESS: at 16.90% examples, 768064 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:16,232 : INFO : EPOCH 4 - PROGRESS: at 21.38% examples, 807589 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:17,242 : INFO : EPOCH 4 - PROGRESS: at 25.91% examples, 840007 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:18,242 : INFO : EPOCH 4 - PROGRESS: at 30.45% examples, 863356 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:19,244 : INFO : EPOCH 4 - PROGRESS: at 34.93% examples, 881337 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:20,249 : INFO : EPOCH 4 - PROGRESS: at 39.36% examples, 897006 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:21,251 : INFO : EPOCH 4 - PROGRESS: at 42.01% examples, 870168 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:22,252 : INFO : EPOCH 4 - PROGRESS: at 44.96% examples, 854131 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:23,253 : INFO : EPOCH 4 - PROGRESS: at 48.61% examples, 853266 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:24,258 : INFO : EPOCH 4 - PROGRESS: at 50.88% examples, 829549 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:25,274 : INFO : EPOCH 4 - PROGRESS: at 54.21% examples, 824331 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:08:26,286 : INFO : EPOCH 4 - PROGRESS: at 57.26% examples, 816146 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:27,292 : INFO : EPOCH 4 - PROGRESS: at 61.23% examples, 821833 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:28,301 : INFO : EPOCH 4 - PROGRESS: at 64.62% examples, 819258 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:08:29,323 : INFO : EPOCH 4 - PROGRESS: at 67.69% examples, 811857 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:30,330 : INFO : EPOCH 4 - PROGRESS: at 71.20% examples, 810697 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:31,329 : INFO : EPOCH 4 - PROGRESS: at 75.18% examples, 815150 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:08:32,351 : INFO : EPOCH 4 - PROGRESS: at 78.45% examples, 811269 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:33,372 : INFO : EPOCH 4 - PROGRESS: at 81.08% examples, 801581 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:34,388 : INFO : EPOCH 4 - PROGRESS: at 85.04% examples, 805771 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:35,399 : INFO : EPOCH 4 - PROGRESS: at 88.25% examples, 803024 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:36,400 : INFO : EPOCH 4 - PROGRESS: at 91.85% examples, 803326 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:37,402 : INFO : EPOCH 4 - PROGRESS: at 96.35% examples, 811851 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:38,184 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:08:38,208 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:08:38,213 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:08:38,216 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:08:38,218 : INFO : EPOCH - 4 : training on 23279529 raw words (22951015 effective words) took 28.1s, 817917 effective words/s
# 2019-11-21 17:08:39,246 : INFO : EPOCH 5 - PROGRESS: at 4.22% examples, 956577 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:08:40,250 : INFO : EPOCH 5 - PROGRESS: at 8.02% examples, 921433 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:41,267 : INFO : EPOCH 5 - PROGRESS: at 12.10% examples, 918835 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:42,275 : INFO : EPOCH 5 - PROGRESS: at 16.70% examples, 948942 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:08:43,285 : INFO : EPOCH 5 - PROGRESS: at 21.31% examples, 965180 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:44,290 : INFO : EPOCH 5 - PROGRESS: at 25.82% examples, 977586 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:45,299 : INFO : EPOCH 5 - PROGRESS: at 29.27% examples, 947938 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:46,303 : INFO : EPOCH 5 - PROGRESS: at 32.82% examples, 930895 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:47,346 : INFO : EPOCH 5 - PROGRESS: at 35.12% examples, 882882 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:48,359 : INFO : EPOCH 5 - PROGRESS: at 37.83% examples, 858614 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:49,360 : INFO : EPOCH 5 - PROGRESS: at 41.77% examples, 861515 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:50,364 : INFO : EPOCH 5 - PROGRESS: at 46.09% examples, 873243 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:08:51,374 : INFO : EPOCH 5 - PROGRESS: at 50.63% examples, 884984 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:52,379 : INFO : EPOCH 5 - PROGRESS: at 54.95% examples, 892505 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:53,381 : INFO : EPOCH 5 - PROGRESS: at 59.15% examples, 897674 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:54,386 : INFO : EPOCH 5 - PROGRESS: at 63.28% examples, 900547 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:55,395 : INFO : EPOCH 5 - PROGRESS: at 67.66% examples, 905521 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:56,410 : INFO : EPOCH 5 - PROGRESS: at 72.07% examples, 910344 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:57,412 : INFO : EPOCH 5 - PROGRESS: at 76.66% examples, 916577 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:08:58,415 : INFO : EPOCH 5 - PROGRESS: at 81.13% examples, 922052 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:08:59,419 : INFO : EPOCH 5 - PROGRESS: at 85.63% examples, 927911 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:00,431 : INFO : EPOCH 5 - PROGRESS: at 90.05% examples, 930986 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:01,435 : INFO : EPOCH 5 - PROGRESS: at 94.57% examples, 934973 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 17:09:02,448 : INFO : EPOCH 5 - PROGRESS: at 99.11% examples, 939054 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 17:09:02,620 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:09:02,623 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:09:02,643 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:09:02,646 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:09:02,648 : INFO : EPOCH - 5 : training on 23279529 raw words (22951015 effective words) took 24.4s, 939630 effective words/s
# 2019-11-21 17:09:03,677 : INFO : EPOCH 6 - PROGRESS: at 4.31% examples, 984448 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:04,680 : INFO : EPOCH 6 - PROGRESS: at 8.76% examples, 1011355 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:09:05,700 : INFO : EPOCH 6 - PROGRESS: at 13.36% examples, 1016468 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:06,704 : INFO : EPOCH 6 - PROGRESS: at 17.90% examples, 1020421 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:07,711 : INFO : EPOCH 6 - PROGRESS: at 22.56% examples, 1025114 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:08,718 : INFO : EPOCH 6 - PROGRESS: at 27.16% examples, 1029034 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:09,722 : INFO : EPOCH 6 - PROGRESS: at 31.22% examples, 1013373 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:09:10,743 : INFO : EPOCH 6 - PROGRESS: at 34.96% examples, 992157 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:11,744 : INFO : EPOCH 6 - PROGRESS: at 39.10% examples, 990263 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:12,745 : INFO : EPOCH 6 - PROGRESS: at 43.67% examples, 994669 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:13,748 : INFO : EPOCH 6 - PROGRESS: at 48.15% examples, 998295 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:14,750 : INFO : EPOCH 6 - PROGRESS: at 52.69% examples, 1002068 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:15,751 : INFO : EPOCH 6 - PROGRESS: at 57.26% examples, 1005612 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:16,753 : INFO : EPOCH 6 - PROGRESS: at 61.73% examples, 1007706 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:17,753 : INFO : EPOCH 6 - PROGRESS: at 66.32% examples, 1009902 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:18,770 : INFO : EPOCH 6 - PROGRESS: at 70.89% examples, 1010973 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:19,779 : INFO : EPOCH 6 - PROGRESS: at 75.55% examples, 1012800 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:20,783 : INFO : EPOCH 6 - PROGRESS: at 80.06% examples, 1013986 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:09:21,786 : INFO : EPOCH 6 - PROGRESS: at 84.56% examples, 1014836 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:22,793 : INFO : EPOCH 6 - PROGRESS: at 89.02% examples, 1015612 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:23,819 : INFO : EPOCH 6 - PROGRESS: at 93.54% examples, 1014804 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:24,822 : INFO : EPOCH 6 - PROGRESS: at 98.10% examples, 1016530 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:25,228 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:09:25,248 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:09:25,250 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:09:25,251 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:09:25,252 : INFO : EPOCH - 6 : training on 23279529 raw words (22951015 effective words) took 22.6s, 1015994 effective words/s
# 2019-11-21 17:09:26,267 : INFO : EPOCH 7 - PROGRESS: at 4.45% examples, 1016953 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:27,285 : INFO : EPOCH 7 - PROGRESS: at 8.95% examples, 1030107 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:28,288 : INFO : EPOCH 7 - PROGRESS: at 13.64% examples, 1041132 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:29,293 : INFO : EPOCH 7 - PROGRESS: at 18.25% examples, 1040655 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:30,300 : INFO : EPOCH 7 - PROGRESS: at 22.89% examples, 1041846 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:31,302 : INFO : EPOCH 7 - PROGRESS: at 27.43% examples, 1040554 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:09:32,303 : INFO : EPOCH 7 - PROGRESS: at 32.00% examples, 1040104 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:33,307 : INFO : EPOCH 7 - PROGRESS: at 36.43% examples, 1040319 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:34,311 : INFO : EPOCH 7 - PROGRESS: at 40.96% examples, 1039392 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:35,313 : INFO : EPOCH 7 - PROGRESS: at 45.49% examples, 1039882 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:36,327 : INFO : EPOCH 7 - PROGRESS: at 50.08% examples, 1039913 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:37,340 : INFO : EPOCH 7 - PROGRESS: at 54.62% examples, 1039277 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:38,348 : INFO : EPOCH 7 - PROGRESS: at 59.15% examples, 1039445 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:39,359 : INFO : EPOCH 7 - PROGRESS: at 63.40% examples, 1034111 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:40,377 : INFO : EPOCH 7 - PROGRESS: at 67.28% examples, 1022652 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:41,379 : INFO : EPOCH 7 - PROGRESS: at 71.46% examples, 1017970 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:42,381 : INFO : EPOCH 7 - PROGRESS: at 76.00% examples, 1018629 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:09:43,397 : INFO : EPOCH 7 - PROGRESS: at 80.35% examples, 1016661 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:44,415 : INFO : EPOCH 7 - PROGRESS: at 84.56% examples, 1013042 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:45,420 : INFO : EPOCH 7 - PROGRESS: at 89.06% examples, 1014431 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:09:46,425 : INFO : EPOCH 7 - PROGRESS: at 93.63% examples, 1015125 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:47,427 : INFO : EPOCH 7 - PROGRESS: at 98.15% examples, 1016492 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:47,788 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:09:47,810 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:09:47,813 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:09:47,815 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:09:47,816 : INFO : EPOCH - 7 : training on 23279529 raw words (22951015 effective words) took 22.6s, 1017372 effective words/s
# 2019-11-21 17:09:48,830 : INFO : EPOCH 8 - PROGRESS: at 4.44% examples, 1019367 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:49,844 : INFO : EPOCH 8 - PROGRESS: at 8.91% examples, 1028485 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:50,856 : INFO : EPOCH 8 - PROGRESS: at 13.47% examples, 1027785 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:51,860 : INFO : EPOCH 8 - PROGRESS: at 18.07% examples, 1030917 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:52,861 : INFO : EPOCH 8 - PROGRESS: at 22.69% examples, 1033008 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:09:53,870 : INFO : EPOCH 8 - PROGRESS: at 26.86% examples, 1019261 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:54,889 : INFO : EPOCH 8 - PROGRESS: at 30.80% examples, 998684 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:09:55,890 : INFO : EPOCH 8 - PROGRESS: at 35.20% examples, 1000881 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:56,893 : INFO : EPOCH 8 - PROGRESS: at 39.52% examples, 1002127 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:09:57,903 : INFO : EPOCH 8 - PROGRESS: at 43.87% examples, 999848 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:09:58,911 : INFO : EPOCH 8 - PROGRESS: at 48.07% examples, 996290 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:09:59,918 : INFO : EPOCH 8 - PROGRESS: at 52.36% examples, 995023 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:00,925 : INFO : EPOCH 8 - PROGRESS: at 56.53% examples, 992101 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:01,930 : INFO : EPOCH 8 - PROGRESS: at 60.95% examples, 993371 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:02,944 : INFO : EPOCH 8 - PROGRESS: at 65.51% examples, 995811 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:03,956 : INFO : EPOCH 8 - PROGRESS: at 70.13% examples, 998586 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:04,966 : INFO : EPOCH 8 - PROGRESS: at 74.69% examples, 1000393 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:10:05,977 : INFO : EPOCH 8 - PROGRESS: at 79.28% examples, 1002492 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:06,986 : INFO : EPOCH 8 - PROGRESS: at 83.91% examples, 1004252 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:07,999 : INFO : EPOCH 8 - PROGRESS: at 88.43% examples, 1006546 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:09,000 : INFO : EPOCH 8 - PROGRESS: at 92.93% examples, 1006923 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:10,010 : INFO : EPOCH 8 - PROGRESS: at 96.72% examples, 1000785 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:10:10,803 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:10:10,822 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:10:10,841 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:10:10,857 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:10:10,858 : INFO : EPOCH - 8 : training on 23279529 raw words (22951015 effective words) took 23.0s, 996324 effective words/s
# 2019-11-21 17:10:11,884 : INFO : EPOCH 9 - PROGRESS: at 4.35% examples, 990593 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:10:12,892 : INFO : EPOCH 9 - PROGRESS: at 8.59% examples, 988728 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:13,899 : INFO : EPOCH 9 - PROGRESS: at 11.78% examples, 896904 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:14,905 : INFO : EPOCH 9 - PROGRESS: at 14.64% examples, 836660 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:15,911 : INFO : EPOCH 9 - PROGRESS: at 17.45% examples, 796476 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:16,912 : INFO : EPOCH 9 - PROGRESS: at 20.78% examples, 787522 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:17,948 : INFO : EPOCH 9 - PROGRESS: at 23.64% examples, 766495 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:10:18,958 : INFO : EPOCH 9 - PROGRESS: at 26.59% examples, 754599 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:19,959 : INFO : EPOCH 9 - PROGRESS: at 30.02% examples, 756980 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:20,987 : INFO : EPOCH 9 - PROGRESS: at 34.15% examples, 773056 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:21,990 : INFO : EPOCH 9 - PROGRESS: at 37.14% examples, 767638 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:23,008 : INFO : EPOCH 9 - PROGRESS: at 40.74% examples, 771059 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:24,014 : INFO : EPOCH 9 - PROGRESS: at 45.06% examples, 787235 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:25,026 : INFO : EPOCH 9 - PROGRESS: at 49.43% examples, 802154 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:26,033 : INFO : EPOCH 9 - PROGRESS: at 53.78% examples, 815200 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:27,040 : INFO : EPOCH 9 - PROGRESS: at 58.09% examples, 825759 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 17:10:28,044 : INFO : EPOCH 9 - PROGRESS: at 62.44% examples, 836220 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:29,045 : INFO : EPOCH 9 - PROGRESS: at 66.82% examples, 844788 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:30,072 : INFO : EPOCH 9 - PROGRESS: at 71.28% examples, 852512 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:10:31,076 : INFO : EPOCH 9 - PROGRESS: at 75.77% examples, 860252 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:10:32,080 : INFO : EPOCH 9 - PROGRESS: at 80.14% examples, 867107 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:10:33,085 : INFO : EPOCH 9 - PROGRESS: at 84.47% examples, 872613 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:34,092 : INFO : EPOCH 9 - PROGRESS: at 88.78% examples, 877759 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:35,097 : INFO : EPOCH 9 - PROGRESS: at 93.18% examples, 882469 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:36,104 : INFO : EPOCH 9 - PROGRESS: at 97.50% examples, 887142 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:36,638 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:10:36,640 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:10:36,668 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:10:36,671 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:10:36,672 : INFO : EPOCH - 9 : training on 23279529 raw words (22951015 effective words) took 25.8s, 889386 effective words/s
# 2019-11-21 17:10:37,689 : INFO : EPOCH 10 - PROGRESS: at 4.27% examples, 977156 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:38,714 : INFO : EPOCH 10 - PROGRESS: at 8.59% examples, 982920 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:39,727 : INFO : EPOCH 10 - PROGRESS: at 12.61% examples, 955043 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:40,738 : INFO : EPOCH 10 - PROGRESS: at 16.41% examples, 932155 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:41,755 : INFO : EPOCH 10 - PROGRESS: at 20.69% examples, 933723 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:42,769 : INFO : EPOCH 10 - PROGRESS: at 25.03% examples, 943447 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:43,774 : INFO : EPOCH 10 - PROGRESS: at 29.44% examples, 950658 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:44,802 : INFO : EPOCH 10 - PROGRESS: at 33.90% examples, 955740 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:45,833 : INFO : EPOCH 10 - PROGRESS: at 38.20% examples, 959941 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:46,834 : INFO : EPOCH 10 - PROGRESS: at 42.68% examples, 965588 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:47,842 : INFO : EPOCH 10 - PROGRESS: at 46.97% examples, 967774 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:48,903 : INFO : EPOCH 10 - PROGRESS: at 50.79% examples, 955129 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:10:49,968 : INFO : EPOCH 10 - PROGRESS: at 50.95% examples, 881580 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:51,377 : INFO : EPOCH 10 - PROGRESS: at 51.21% examples, 800983 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:52,386 : INFO : EPOCH 10 - PROGRESS: at 51.52% examples, 753895 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:53,567 : INFO : EPOCH 10 - PROGRESS: at 51.73% examples, 704004 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:54,572 : INFO : EPOCH 10 - PROGRESS: at 53.83% examples, 691439 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:55,604 : INFO : EPOCH 10 - PROGRESS: at 56.53% examples, 686761 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:56,622 : INFO : EPOCH 10 - PROGRESS: at 59.36% examples, 684631 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:57,640 : INFO : EPOCH 10 - PROGRESS: at 62.15% examples, 681953 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:58,673 : INFO : EPOCH 10 - PROGRESS: at 64.97% examples, 679291 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:10:59,697 : INFO : EPOCH 10 - PROGRESS: at 67.77% examples, 676755 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:00,707 : INFO : EPOCH 10 - PROGRESS: at 70.41% examples, 673239 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:01,711 : INFO : EPOCH 10 - PROGRESS: at 73.11% examples, 671052 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:02,712 : INFO : EPOCH 10 - PROGRESS: at 75.77% examples, 667726 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:03,719 : INFO : EPOCH 10 - PROGRESS: at 78.28% examples, 664364 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:04,753 : INFO : EPOCH 10 - PROGRESS: at 80.81% examples, 660692 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:05,761 : INFO : EPOCH 10 - PROGRESS: at 83.48% examples, 658384 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:06,764 : INFO : EPOCH 10 - PROGRESS: at 85.94% examples, 655954 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:07,764 : INFO : EPOCH 10 - PROGRESS: at 88.64% examples, 654828 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:08,784 : INFO : EPOCH 10 - PROGRESS: at 91.38% examples, 653258 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:09,828 : INFO : EPOCH 10 - PROGRESS: at 93.84% examples, 649670 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:10,836 : INFO : EPOCH 10 - PROGRESS: at 96.16% examples, 646077 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:11,839 : INFO : EPOCH 10 - PROGRESS: at 98.53% examples, 643374 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:12,414 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:11:12,428 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:11:12,436 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:11:12,489 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:11:12,492 : INFO : EPOCH - 10 : training on 23279529 raw words (22951015 effective words) took 35.8s, 640811 effective words/s
# 2019-11-21 17:11:13,545 : INFO : EPOCH 11 - PROGRESS: at 2.38% examples, 528818 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:11:14,594 : INFO : EPOCH 11 - PROGRESS: at 5.08% examples, 565217 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 17:11:15,600 : INFO : EPOCH 11 - PROGRESS: at 7.61% examples, 572242 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:16,629 : INFO : EPOCH 11 - PROGRESS: at 10.29% examples, 579180 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:17,633 : INFO : EPOCH 11 - PROGRESS: at 13.06% examples, 588723 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:18,649 : INFO : EPOCH 11 - PROGRESS: at 14.81% examples, 555982 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:19,668 : INFO : EPOCH 11 - PROGRESS: at 16.74% examples, 538016 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:11:20,690 : INFO : EPOCH 11 - PROGRESS: at 18.70% examples, 524932 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:21,692 : INFO : EPOCH 11 - PROGRESS: at 21.34% examples, 532735 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:22,696 : INFO : EPOCH 11 - PROGRESS: at 24.00% examples, 540952 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:23,704 : INFO : EPOCH 11 - PROGRESS: at 26.59% examples, 545080 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:24,732 : INFO : EPOCH 11 - PROGRESS: at 29.31% examples, 549345 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:11:25,767 : INFO : EPOCH 11 - PROGRESS: at 31.05% examples, 536407 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:26,787 : INFO : EPOCH 11 - PROGRESS: at 33.20% examples, 532765 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:11:27,808 : INFO : EPOCH 11 - PROGRESS: at 35.52% examples, 532684 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:28,813 : INFO : EPOCH 11 - PROGRESS: at 37.19% examples, 524102 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:29,837 : INFO : EPOCH 11 - PROGRESS: at 39.64% examples, 526082 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:30,843 : INFO : EPOCH 11 - PROGRESS: at 42.36% examples, 530580 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:31,852 : INFO : EPOCH 11 - PROGRESS: at 44.89% examples, 532904 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:32,878 : INFO : EPOCH 11 - PROGRESS: at 47.32% examples, 534136 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:33,902 : INFO : EPOCH 11 - PROGRESS: at 50.03% examples, 537527 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:34,917 : INFO : EPOCH 11 - PROGRESS: at 52.79% examples, 541281 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:35,975 : INFO : EPOCH 11 - PROGRESS: at 54.66% examples, 535409 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:11:36,976 : INFO : EPOCH 11 - PROGRESS: at 56.57% examples, 531525 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:38,002 : INFO : EPOCH 11 - PROGRESS: at 59.25% examples, 534404 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:39,024 : INFO : EPOCH 11 - PROGRESS: at 61.90% examples, 536843 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:40,026 : INFO : EPOCH 11 - PROGRESS: at 64.20% examples, 536568 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:41,038 : INFO : EPOCH 11 - PROGRESS: at 65.88% examples, 530751 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:42,089 : INFO : EPOCH 11 - PROGRESS: at 67.65% examples, 525585 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:43,109 : INFO : EPOCH 11 - PROGRESS: at 69.25% examples, 519788 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:44,131 : INFO : EPOCH 11 - PROGRESS: at 71.24% examples, 517358 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:45,186 : INFO : EPOCH 11 - PROGRESS: at 72.91% examples, 512533 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:46,200 : INFO : EPOCH 11 - PROGRESS: at 74.42% examples, 507227 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:47,209 : INFO : EPOCH 11 - PROGRESS: at 76.13% examples, 503444 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:11:48,219 : INFO : EPOCH 11 - PROGRESS: at 78.07% examples, 501675 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:49,254 : INFO : EPOCH 11 - PROGRESS: at 79.67% examples, 497592 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:50,285 : INFO : EPOCH 11 - PROGRESS: at 81.30% examples, 493792 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:51,293 : INFO : EPOCH 11 - PROGRESS: at 83.57% examples, 494124 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:52,313 : INFO : EPOCH 11 - PROGRESS: at 86.14% examples, 496983 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:53,344 : INFO : EPOCH 11 - PROGRESS: at 88.90% examples, 499865 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:54,348 : INFO : EPOCH 11 - PROGRESS: at 91.34% examples, 501010 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:55,349 : INFO : EPOCH 11 - PROGRESS: at 93.47% examples, 500639 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:56,362 : INFO : EPOCH 11 - PROGRESS: at 96.11% examples, 502983 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:57,369 : INFO : EPOCH 11 - PROGRESS: at 98.78% examples, 505311 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:57,798 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:11:57,820 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:11:57,846 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:11:57,853 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:11:57,857 : INFO : EPOCH - 11 : training on 23279529 raw words (22951015 effective words) took 45.4s, 506031 effective words/s
# 2019-11-21 17:11:58,877 : INFO : EPOCH 12 - PROGRESS: at 2.58% examples, 594190 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:11:59,891 : INFO : EPOCH 12 - PROGRESS: at 5.30% examples, 608146 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:00,917 : INFO : EPOCH 12 - PROGRESS: at 7.86% examples, 600264 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 17:12:01,919 : INFO : EPOCH 12 - PROGRESS: at 10.56% examples, 604483 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:02,944 : INFO : EPOCH 12 - PROGRESS: at 12.90% examples, 587480 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:03,948 : INFO : EPOCH 12 - PROGRESS: at 15.31% examples, 581243 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:04,964 : INFO : EPOCH 12 - PROGRESS: at 17.61% examples, 571562 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:06,030 : INFO : EPOCH 12 - PROGRESS: at 20.02% examples, 562136 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:07,065 : INFO : EPOCH 12 - PROGRESS: at 22.09% examples, 551283 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:12:08,078 : INFO : EPOCH 12 - PROGRESS: at 23.80% examples, 535371 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:09,084 : INFO : EPOCH 12 - PROGRESS: at 25.53% examples, 522815 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:10,124 : INFO : EPOCH 12 - PROGRESS: at 27.95% examples, 522737 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:11,130 : INFO : EPOCH 12 - PROGRESS: at 30.33% examples, 524153 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:12,159 : INFO : EPOCH 12 - PROGRESS: at 32.58% examples, 522322 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:12:13,163 : INFO : EPOCH 12 - PROGRESS: at 34.43% examples, 515991 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 17:12:14,176 : INFO : EPOCH 12 - PROGRESS: at 36.59% examples, 515929 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:15,175 : INFO : EPOCH 12 - PROGRESS: at 38.98% examples, 517950 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:16,209 : INFO : EPOCH 12 - PROGRESS: at 41.55% examples, 520525 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:17,214 : INFO : EPOCH 12 - PROGRESS: at 44.04% examples, 522956 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:18,225 : INFO : EPOCH 12 - PROGRESS: at 46.68% examples, 527493 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:19,228 : INFO : EPOCH 12 - PROGRESS: at 49.43% examples, 531712 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:20,239 : INFO : EPOCH 12 - PROGRESS: at 52.20% examples, 536245 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:21,253 : INFO : EPOCH 12 - PROGRESS: at 54.92% examples, 539867 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:22,266 : INFO : EPOCH 12 - PROGRESS: at 57.60% examples, 542617 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:23,278 : INFO : EPOCH 12 - PROGRESS: at 60.26% examples, 545429 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:24,298 : INFO : EPOCH 12 - PROGRESS: at 62.81% examples, 546702 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:25,318 : INFO : EPOCH 12 - PROGRESS: at 65.55% examples, 548904 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:26,324 : INFO : EPOCH 12 - PROGRESS: at 68.21% examples, 550852 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:12:27,326 : INFO : EPOCH 12 - PROGRESS: at 70.89% examples, 552828 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:28,342 : INFO : EPOCH 12 - PROGRESS: at 73.65% examples, 555118 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:29,385 : INFO : EPOCH 12 - PROGRESS: at 76.45% examples, 556536 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:30,388 : INFO : EPOCH 12 - PROGRESS: at 79.24% examples, 559335 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:31,394 : INFO : EPOCH 12 - PROGRESS: at 82.02% examples, 561369 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:32,400 : INFO : EPOCH 12 - PROGRESS: at 84.70% examples, 562859 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:33,404 : INFO : EPOCH 12 - PROGRESS: at 87.39% examples, 564675 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:34,406 : INFO : EPOCH 12 - PROGRESS: at 90.09% examples, 566150 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:35,430 : INFO : EPOCH 12 - PROGRESS: at 92.88% examples, 567425 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:36,437 : INFO : EPOCH 12 - PROGRESS: at 95.64% examples, 568949 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:37,469 : INFO : EPOCH 12 - PROGRESS: at 98.23% examples, 569541 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:38,079 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:12:38,086 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:12:38,105 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:12:38,117 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:12:38,120 : INFO : EPOCH - 12 : training on 23279529 raw words (22951015 effective words) took 40.3s, 570183 effective words/s
# 2019-11-21 17:12:39,154 : INFO : EPOCH 13 - PROGRESS: at 2.54% examples, 583114 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:40,172 : INFO : EPOCH 13 - PROGRESS: at 5.21% examples, 596292 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:41,197 : INFO : EPOCH 13 - PROGRESS: at 7.19% examples, 548509 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:42,211 : INFO : EPOCH 13 - PROGRESS: at 9.66% examples, 551536 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:43,214 : INFO : EPOCH 13 - PROGRESS: at 12.52% examples, 570684 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:44,215 : INFO : EPOCH 13 - PROGRESS: at 15.91% examples, 604217 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:45,225 : INFO : EPOCH 13 - PROGRESS: at 19.50% examples, 631331 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:46,227 : INFO : EPOCH 13 - PROGRESS: at 23.26% examples, 660572 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:47,244 : INFO : EPOCH 13 - PROGRESS: at 26.56% examples, 669725 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:48,250 : INFO : EPOCH 13 - PROGRESS: at 30.45% examples, 690528 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:49,263 : INFO : EPOCH 13 - PROGRESS: at 34.57% examples, 712295 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:50,263 : INFO : EPOCH 13 - PROGRESS: at 37.83% examples, 718020 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:51,264 : INFO : EPOCH 13 - PROGRESS: at 40.79% examples, 714146 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:52,276 : INFO : EPOCH 13 - PROGRESS: at 44.80% examples, 728186 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:53,278 : INFO : EPOCH 13 - PROGRESS: at 49.05% examples, 744617 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:54,300 : INFO : EPOCH 13 - PROGRESS: at 53.50% examples, 761039 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:55,300 : INFO : EPOCH 13 - PROGRESS: at 58.25% examples, 780639 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:56,309 : INFO : EPOCH 13 - PROGRESS: at 62.81% examples, 795383 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:57,314 : INFO : EPOCH 13 - PROGRESS: at 67.93% examples, 814572 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:12:58,333 : INFO : EPOCH 13 - PROGRESS: at 73.11% examples, 832009 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:12:59,339 : INFO : EPOCH 13 - PROGRESS: at 78.33% examples, 848053 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:00,352 : INFO : EPOCH 13 - PROGRESS: at 83.31% examples, 860386 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:01,366 : INFO : EPOCH 13 - PROGRESS: at 87.89% examples, 869035 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:02,370 : INFO : EPOCH 13 - PROGRESS: at 92.44% examples, 875719 words/s, in_qsize 7, out_qsize 1
# 2019-11-21 17:13:03,370 : INFO : EPOCH 13 - PROGRESS: at 96.56% examples, 878648 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:04,163 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 17:13:04,182 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 17:13:04,187 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 17:13:04,194 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 17:13:04,195 : INFO : EPOCH - 13 : training on 23279529 raw words (22951015 effective words) took 26.1s, 880918 effective words/s
# 2019-11-21 17:13:05,214 : INFO : EPOCH 14 - PROGRESS: at 4.27% examples, 979056 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:06,219 : INFO : EPOCH 14 - PROGRESS: at 8.19% examples, 945854 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:07,220 : INFO : EPOCH 14 - PROGRESS: at 11.83% examples, 905090 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:08,242 : INFO : EPOCH 14 - PROGRESS: at 15.49% examples, 884864 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:13:09,247 : INFO : EPOCH 14 - PROGRESS: at 19.46% examples, 884760 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:10,249 : INFO : EPOCH 14 - PROGRESS: at 23.12% examples, 878530 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:11,259 : INFO : EPOCH 14 - PROGRESS: at 26.60% examples, 865503 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 17:13:12,263 : INFO : EPOCH 14 - PROGRESS: at 31.01% examples, 881592 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:13,305 : INFO : EPOCH 14 - PROGRESS: at 35.23% examples, 888233 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 17:13:14,317 : INFO : EPOCH 14 - PROGRESS: at 38.98% examples, 886435 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 17:13:15,334 : INFO : EPOCH 14 - PROGRESS: at 43.40% examples, 895931 words/s, in_qsize 8, out_qsize 0
# ...
# 2019-11-21 18:10:11,545 : INFO : EPOCH 18 - PROGRESS: at 74.12% examples, 418566 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 18:10:12,604 : INFO : EPOCH 18 - PROGRESS: at 75.97% examples, 417742 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:13,651 : INFO : EPOCH 18 - PROGRESS: at 77.83% examples, 417479 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:14,671 : INFO : EPOCH 18 - PROGRESS: at 79.71% examples, 417742 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:15,688 : INFO : EPOCH 18 - PROGRESS: at 81.63% examples, 418017 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:16,702 : INFO : EPOCH 18 - PROGRESS: at 83.57% examples, 418216 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:17,703 : INFO : EPOCH 18 - PROGRESS: at 85.32% examples, 418328 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:18,741 : INFO : EPOCH 18 - PROGRESS: at 87.21% examples, 418385 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:19,741 : INFO : EPOCH 18 - PROGRESS: at 89.06% examples, 418547 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:20,742 : INFO : EPOCH 18 - PROGRESS: at 91.01% examples, 418822 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:21,765 : INFO : EPOCH 18 - PROGRESS: at 92.88% examples, 418793 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:22,787 : INFO : EPOCH 18 - PROGRESS: at 94.74% examples, 418794 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:23,798 : INFO : EPOCH 18 - PROGRESS: at 96.51% examples, 418626 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:24,798 : INFO : EPOCH 18 - PROGRESS: at 98.39% examples, 418962 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:25,556 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 18:10:25,607 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 18:10:25,626 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 18:10:25,630 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 18:10:25,631 : INFO : EPOCH - 18 : training on 23279529 raw words (22951015 effective words) took 54.8s, 419117 effective words/s
# 2019-11-21 18:10:26,660 : INFO : EPOCH 19 - PROGRESS: at 1.76% examples, 389993 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:27,706 : INFO : EPOCH 19 - PROGRESS: at 3.42% examples, 384482 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:28,717 : INFO : EPOCH 19 - PROGRESS: at 5.17% examples, 390421 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:29,736 : INFO : EPOCH 19 - PROGRESS: at 6.88% examples, 390359 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:30,773 : INFO : EPOCH 19 - PROGRESS: at 8.67% examples, 393870 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:31,808 : INFO : EPOCH 19 - PROGRESS: at 10.56% examples, 396997 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 18:10:32,812 : INFO : EPOCH 19 - PROGRESS: at 12.49% examples, 402196 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:33,834 : INFO : EPOCH 19 - PROGRESS: at 14.36% examples, 405157 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:34,841 : INFO : EPOCH 19 - PROGRESS: at 16.25% examples, 407248 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:35,842 : INFO : EPOCH 19 - PROGRESS: at 18.16% examples, 409847 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:36,867 : INFO : EPOCH 19 - PROGRESS: at 20.06% examples, 409511 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:37,879 : INFO : EPOCH 19 - PROGRESS: at 21.92% examples, 411075 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:38,954 : INFO : EPOCH 19 - PROGRESS: at 23.84% examples, 411217 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:40,006 : INFO : EPOCH 19 - PROGRESS: at 25.65% examples, 410174 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:41,042 : INFO : EPOCH 19 - PROGRESS: at 27.47% examples, 409016 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:42,048 : INFO : EPOCH 19 - PROGRESS: at 29.27% examples, 408820 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:43,066 : INFO : EPOCH 19 - PROGRESS: at 31.01% examples, 407710 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:44,073 : INFO : EPOCH 19 - PROGRESS: at 32.70% examples, 406500 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 18:10:45,083 : INFO : EPOCH 19 - PROGRESS: at 34.62% examples, 407870 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:46,087 : INFO : EPOCH 19 - PROGRESS: at 36.39% examples, 409103 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:47,138 : INFO : EPOCH 19 - PROGRESS: at 38.24% examples, 409319 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:48,139 : INFO : EPOCH 19 - PROGRESS: at 40.16% examples, 410467 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:49,163 : INFO : EPOCH 19 - PROGRESS: at 42.05% examples, 410768 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:50,178 : INFO : EPOCH 19 - PROGRESS: at 43.99% examples, 411911 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:51,201 : INFO : EPOCH 19 - PROGRESS: at 45.83% examples, 412134 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:52,210 : INFO : EPOCH 19 - PROGRESS: at 47.67% examples, 412498 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 18:10:53,215 : INFO : EPOCH 19 - PROGRESS: at 49.58% examples, 413279 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 18:10:54,238 : INFO : EPOCH 19 - PROGRESS: at 51.39% examples, 413088 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:55,261 : INFO : EPOCH 19 - PROGRESS: at 53.34% examples, 413833 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:56,271 : INFO : EPOCH 19 - PROGRESS: at 55.21% examples, 414370 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:57,288 : INFO : EPOCH 19 - PROGRESS: at 57.10% examples, 414699 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:58,306 : INFO : EPOCH 19 - PROGRESS: at 58.90% examples, 414780 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:10:59,318 : INFO : EPOCH 19 - PROGRESS: at 60.82% examples, 415268 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:00,332 : INFO : EPOCH 19 - PROGRESS: at 62.69% examples, 415686 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:01,343 : INFO : EPOCH 19 - PROGRESS: at 64.54% examples, 415795 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:02,344 : INFO : EPOCH 19 - PROGRESS: at 66.43% examples, 416017 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:03,363 : INFO : EPOCH 19 - PROGRESS: at 68.34% examples, 416313 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:04,365 : INFO : EPOCH 19 - PROGRESS: at 70.21% examples, 416538 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:05,385 : INFO : EPOCH 19 - PROGRESS: at 72.12% examples, 416827 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 18:11:06,400 : INFO : EPOCH 19 - PROGRESS: at 73.99% examples, 416954 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:07,405 : INFO : EPOCH 19 - PROGRESS: at 75.93% examples, 417171 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:08,416 : INFO : EPOCH 19 - PROGRESS: at 77.83% examples, 417509 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:09,439 : INFO : EPOCH 19 - PROGRESS: at 79.58% examples, 417082 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:10,443 : INFO : EPOCH 19 - PROGRESS: at 81.38% examples, 416833 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:11,514 : INFO : EPOCH 19 - PROGRESS: at 83.14% examples, 415713 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:12,552 : INFO : EPOCH 19 - PROGRESS: at 84.82% examples, 414945 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:13,578 : INFO : EPOCH 19 - PROGRESS: at 86.40% examples, 413931 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:14,587 : INFO : EPOCH 19 - PROGRESS: at 88.22% examples, 413907 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:15,596 : INFO : EPOCH 19 - PROGRESS: at 90.09% examples, 414084 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:16,615 : INFO : EPOCH 19 - PROGRESS: at 92.01% examples, 414322 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:17,670 : INFO : EPOCH 19 - PROGRESS: at 93.98% examples, 414497 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:18,677 : INFO : EPOCH 19 - PROGRESS: at 95.87% examples, 414836 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:19,678 : INFO : EPOCH 19 - PROGRESS: at 97.63% examples, 414880 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:20,680 : INFO : EPOCH 19 - PROGRESS: at 99.58% examples, 415241 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:20,859 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 18:11:20,862 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 18:11:20,879 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 18:11:20,881 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 18:11:20,883 : INFO : EPOCH - 19 : training on 23279529 raw words (22951015 effective words) took 55.2s, 415451 effective words/s
# 2019-11-21 18:11:21,904 : INFO : EPOCH 20 - PROGRESS: at 1.79% examples, 402324 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:22,929 : INFO : EPOCH 20 - PROGRESS: at 3.58% examples, 408932 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:23,932 : INFO : EPOCH 20 - PROGRESS: at 5.42% examples, 414034 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:24,950 : INFO : EPOCH 20 - PROGRESS: at 7.33% examples, 420023 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:25,960 : INFO : EPOCH 20 - PROGRESS: at 9.13% examples, 419728 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:26,984 : INFO : EPOCH 20 - PROGRESS: at 11.03% examples, 419346 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 18:11:28,008 : INFO : EPOCH 20 - PROGRESS: at 12.94% examples, 420312 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:29,015 : INFO : EPOCH 20 - PROGRESS: at 14.84% examples, 421891 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:30,031 : INFO : EPOCH 20 - PROGRESS: at 16.78% examples, 422797 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:31,074 : INFO : EPOCH 20 - PROGRESS: at 18.75% examples, 422997 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:32,098 : INFO : EPOCH 20 - PROGRESS: at 20.66% examples, 422228 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 18:11:33,151 : INFO : EPOCH 20 - PROGRESS: at 22.43% examples, 419850 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:34,186 : INFO : EPOCH 20 - PROGRESS: at 24.26% examples, 419175 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 18:11:35,190 : INFO : EPOCH 20 - PROGRESS: at 26.04% examples, 418203 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:36,197 : INFO : EPOCH 20 - PROGRESS: at 27.78% examples, 416013 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:37,210 : INFO : EPOCH 20 - PROGRESS: at 29.60% examples, 415808 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:38,210 : INFO : EPOCH 20 - PROGRESS: at 31.49% examples, 416431 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:39,240 : INFO : EPOCH 20 - PROGRESS: at 33.29% examples, 415794 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:40,249 : INFO : EPOCH 20 - PROGRESS: at 35.00% examples, 414630 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:41,256 : INFO : EPOCH 20 - PROGRESS: at 36.73% examples, 414517 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:42,260 : INFO : EPOCH 20 - PROGRESS: at 38.37% examples, 413160 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 18:11:43,278 : INFO : EPOCH 20 - PROGRESS: at 40.21% examples, 412947 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:44,293 : INFO : EPOCH 20 - PROGRESS: at 42.09% examples, 413330 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:45,303 : INFO : EPOCH 20 - PROGRESS: at 43.95% examples, 413654 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 18:11:46,334 : INFO : EPOCH 20 - PROGRESS: at 45.89% examples, 414790 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:47,356 : INFO : EPOCH 20 - PROGRESS: at 47.80% examples, 415255 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:48,397 : INFO : EPOCH 20 - PROGRESS: at 49.74% examples, 415726 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:49,405 : INFO : EPOCH 20 - PROGRESS: at 51.65% examples, 416340 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:50,411 : INFO : EPOCH 20 - PROGRESS: at 53.45% examples, 416223 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:51,412 : INFO : EPOCH 20 - PROGRESS: at 55.28% examples, 416469 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:52,421 : INFO : EPOCH 20 - PROGRESS: at 57.14% examples, 416539 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:53,424 : INFO : EPOCH 20 - PROGRESS: at 58.95% examples, 416769 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:54,426 : INFO : EPOCH 20 - PROGRESS: at 60.82% examples, 417050 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:55,441 : INFO : EPOCH 20 - PROGRESS: at 62.64% examples, 417112 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:56,458 : INFO : EPOCH 20 - PROGRESS: at 64.54% examples, 417385 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:57,482 : INFO : EPOCH 20 - PROGRESS: at 66.52% examples, 417848 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:58,482 : INFO : EPOCH 20 - PROGRESS: at 68.41% examples, 418283 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:11:59,531 : INFO : EPOCH 20 - PROGRESS: at 70.33% examples, 418200 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:00,531 : INFO : EPOCH 20 - PROGRESS: at 72.17% examples, 418172 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:01,554 : INFO : EPOCH 20 - PROGRESS: at 74.03% examples, 418193 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:02,615 : INFO : EPOCH 20 - PROGRESS: at 75.97% examples, 417828 words/s, in_qsize 8, out_qsize 1
# 2019-11-21 18:12:03,623 : INFO : EPOCH 20 - PROGRESS: at 77.83% examples, 417941 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:04,628 : INFO : EPOCH 20 - PROGRESS: at 79.71% examples, 418336 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:05,636 : INFO : EPOCH 20 - PROGRESS: at 81.63% examples, 418689 words/s, in_qsize 8, out_qsize 0
# 2019-11-21 18:12:06,643 : INFO : EPOCH 20 - PROGRESS: at 83.57% examples, 418931 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:07,668 : INFO : EPOCH 20 - PROGRESS: at 85.32% examples, 418829 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:08,683 : INFO : EPOCH 20 - PROGRESS: at 87.17% examples, 418857 words/s, in_qsize 6, out_qsize 1
# 2019-11-21 18:12:09,693 : INFO : EPOCH 20 - PROGRESS: at 88.94% examples, 418530 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:10,698 : INFO : EPOCH 20 - PROGRESS: at 90.70% examples, 417993 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:11,703 : INFO : EPOCH 20 - PROGRESS: at 92.44% examples, 417547 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:12,707 : INFO : EPOCH 20 - PROGRESS: at 94.23% examples, 417344 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:13,723 : INFO : EPOCH 20 - PROGRESS: at 96.03% examples, 417189 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:14,739 : INFO : EPOCH 20 - PROGRESS: at 97.89% examples, 417421 words/s, in_qsize 7, out_qsize 0
# 2019-11-21 18:12:15,760 : INFO : EPOCH 20 - PROGRESS: at 99.83% examples, 417593 words/s, in_qsize 4, out_qsize 0
# 2019-11-21 18:12:15,773 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2019-11-21 18:12:15,812 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2019-11-21 18:12:15,823 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2019-11-21 18:12:15,832 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2019-11-21 18:12:15,834 : INFO : EPOCH - 20 : training on 23279529 raw words (22951015 effective words) took 54.9s, 417720 effective words/s
# 2019-11-21 18:12:15,835 : INFO : training on a 465590580 raw words (459020300 effective words) took 2227.7s, 206048 effective words/s
# Evaluating Doc2Vec(dm/c,d100,n5,w5,mc2,t4)
#
# 0.306080 Doc2Vec(dm/c,d100,n5,w5,mc2,t4)
#
#
# Evaluating Doc2Vec(dbow,d100,n5,mc2,t4)+Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t4)
#
# 0.104360 Doc2Vec(dbow,d100,n5,mc2,t4)+Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t4)
#
#
# Evaluating Doc2Vec(dbow,d100,n5,mc2,t4)+Doc2Vec(dm/c,d100,n5,w5,mc2,t4)
#
# 0.104840 Doc2Vec(dbow,d100,n5,mc2,t4)+Doc2Vec(dm/c,d100,n5,w5,mc2,t4)

# %% [markdown]
# Achieved Sentiment-Prediction Accuracy
# --------------------------------------
# Compare error rates achieved, best-to-worst

# %%
print("Err_rate Model")
for rate, name in sorted((rate, name) for name, rate in error_rates.items()):
    print("%f %s" % (rate, name))
# Out:
# Err_rate Model
# 0.104360 Doc2Vec(dbow,d100,n5,mc2,t4)+Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t4)
# 0.104840 Doc2Vec(dbow,d100,n5,mc2,t4)+Doc2Vec(dm/c,d100,n5,w5,mc2,t4)
# 0.105920 Doc2Vec(dbow,d100,n5,mc2,t4)
# 0.174240 Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t4)
# 0.306080 Doc2Vec(dm/c,d100,n5,w5,mc2,t4)

# %%
print("Accuracy")

for acc,name in sorted((acc,name) for name, acc in error)

# %% [markdown]
# In our testing, contrary to the results of the paper, on this problem,
# PV-DBOW alone performs as good as anything else. Concatenating vectors from
# different models only sometimes offers a tiny predictive improvement – and
# stays generally close to the best-performing solo model included.
#
# The best results achieved here are just around 10% error rate, still a long
# way from the paper's reported 7.42% error rate.
#
# (Other trials not shown, with larger vectors and other changes, also don't
# come close to the paper's reported value. Others around the net have reported
# a similar inability to reproduce the paper's best numbers. The PV-DM/C mode
# improves a bit with many more training epochs – but doesn't reach parity with
# PV-DBOW.)

# %% [markdown]
# Examining Results
# -----------------
#
# Let's look for answers to the following questions:
#
# #. Are inferred vectors close to the precalculated ones?
# #. Do close documents seem more related than distant ones?
# #. Do the word vectors show useful similarities?
# #. Are the word vectors from this dataset any good at analogies?

# %% [markdown]
# Are inferred vectors close to the precalculated ones?
# -----------------------------------------------------

# %%
doc_id = np.random.randint(simple_models[0].docvecs.count)  # Pick random doc; re-run cell for more examples
print('for doc %d...' % doc_id)
for model in simple_models:
    inferred_docvec = model.infer_vector(alldocs[doc_id].words)
    print('%s:\n %s' % (model, model.docvecs.most_similar([inferred_docvec], topn=3)))
# Out:
# 2019-11-21 18:15:28,126 : INFO : precomputing L2-norms of doc weight vectors
# for doc 71229...
# 2019-11-21 18:15:28,518 : INFO : precomputing L2-norms of doc weight vectors
# 2019-11-21 18:15:28,648 : INFO : precomputing L2-norms of doc weight vectors
# Doc2Vec(dbow,d100,n5,mc2,t4):
#  [(71229, 0.9894205331802368), (49613, 0.5576101541519165), (20334, 0.5438925623893738)]
# Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t4):
#  [(71229, 0.9080021977424622), (49613, 0.5746079087257385), (80528, 0.5528310537338257)]
# Doc2Vec(dm/c,d100,n5,w5,mc2,t4):
#  [(71229, 0.7498977184295654), (61396, 0.4301270842552185), (3886, 0.42097970843315125)]

# %% [markdown]
# (Yes, here the stored vector from 20 epochs of training is usually one of the
# closest to a freshly-inferred vector for the same words. Defaults for
# inference may benefit from tuning for each dataset or model parameters.)

# %% [markdown]
# Do close documents seem more related than distant ones?
# -------------------------------------------------------

# %%
import random

doc_id = np.random.randint(simple_models[0].docvecs.count)  # pick random doc, re-run cell for more examples
model = random.choice(simple_models)  # and a random model
sims = model.docvecs.most_similar(doc_id, topn=model.docvecs.count)  # get *all* similar documents
print(u'TARGET (%d): «%s»\n' % (doc_id, ' '.join(alldocs[doc_id].words)))
print(u'SIMILAR/DISSIMILAR DOCS PER MODEL %s:\n' % model)
for label, index in [('MOST', 0), ('MEDIAN', len(sims)//2), ('LEAST', len(sims) - 1)]:
    s = sims[index]
    i = sims[index][0]
    words = ' '.join(alldocs[i].words)
    print(u'%s %s: «%s»\n' % (label, s, words))
# Out:
# TARGET (20907): «Being a fan of time travel stories I was surprised that there was no 'device' that sent Russell Johnson's character through time. He just appeared in 1865. It was a disappointing part of the episode. I enjoyed the premise of the dangers of 'altering' the future by changing the past. Other Twilight Zone episodes about time travel such as "No Time Like The Past", "Once Upon A Time", etc. were more to my liking because of the uses of time travel 'devices'. Perhaps if Russell Johnson's character had been the same character he played in "Execution" it would have been more acceptable to fans like myself. As sci-fi fans know, no characters really ever have to 'die' in time travel episodes. All sorts of plot 'twists' can be applied in these types of stories. That was the only flaw I could comment on for this episode.»
#
# SIMILAR/DISSIMILAR DOCS PER MODEL Doc2Vec(dm/c,d100,n5,w5,mc2,t4):
#
# MOST (90064, 0.4897709786891937): «Maybe it's because I just recently got into Indian soap operas. Or maybe it's because I am comparing to the other domestic and foreign shows/movies that I've seen over the years. Kasamh Se has to be one of the most frustrating and painful series I've sat through. Most of the time characters seem to be mute and unable to express themselves at times of relevance. People reveal their thoughts aloud when alone just for the camera. I understand wanting the audience to know what's going on, but if the writer/director/producer is looking for realism, they should consider how often they speak monologues to themselves in their lives. And to politely end my tirade, the one thing that annoys me more than the rest is how the show really takes only 10 minutes while the rest of the show just keeps cutting to characters faces repeatedly during seemingly tense moments. While the plot is possibly believable, I think a 15 year old could come up with more content for a 1/2 hour show.»
#
# MEDIAN (4194, -0.008915126323699951): «this is the worst film I've seen in a long long time, never mind the fact that so many useful things keep appearing on this island "how convenient!!!!", the acting is beyond poor from the outset, its like one of those really badly scripted soft porn films on channel 5, a complete waste of time, and i cant remember the lead actors name but i cant believe he still gets work!!! I've never seen him act "I've seen him in lots of films... But I've never seen him act. here are a few of the blaringly obvious errors, apparently petrol lighters still work even when they've been soaked in sea water!!! also according to this film you can walk into the sea naked but come out wearing bikini bottoms (I'm guessing the camera man and editor were students)there are plenty more errors but I'm ranting now, besides its no so much the errors as the cast the script and the whole film avoid at all costs»
#
# LEAST (31081, -0.4150312840938568): «I rarely comment on films but I've read the other comments and I cannot believe that there are people applauding this celluloid rubbish. I know there are certain people who have their own agenda but lets take it on merit; poorly acted, badly shot and the story felt as the director was making it up as he was going along. I am not going to focus on the sexual aspect of the film involving little kids as the makers of the film obviously knew what they wanted and what their audience would want. All I can say is it is a terrible film, the content is poor and offensive, the production is amateurish and I am glad they could not make a film like this legally today»

# %% [markdown]
# Somewhat, in terms of reviewer tone, movie genre, etc... the MOST
# cosine-similar docs usually seem more like the TARGET than the MEDIAN or
# LEAST... especially if the MOST has a cosine-similarity > 0.5. Re-run the
# cell to try another random target document.

# %% [markdown]
# Do the word vectors show useful similarities?
# ---------------------------------------------

# %%
import random

word_models = simple_models[:]

def pick_random_word(model, threshold=10):
    # pick a random word with a suitable number of occurences
    while True:
        word = random.choice(model.wv.index2word)
        if model.wv.vocab[word].count > threshold:
            return word

target_word = pick_random_word(word_models[0])
# or uncomment below line, to just pick a word from the relevant domain:
# target_word = 'comedy/drama'

for model in word_models:
    print('target_word: %r model: %s similar words:' % (target_word, model))
    for i, (word, sim) in enumerate(model.wv.most_similar(target_word, topn=10), 1):
        print('    %d. %.2f %r' % (i, sim, word))
    print()
# Out:
# 2019-11-21 18:20:41,863 : INFO : precomputing L2-norms of word weight vectors
# target_word: '(Ron' model: Doc2Vec(dbow,d100,n5,mc2,t4) similar words:
# 2019-11-21 18:20:42,168 : INFO : precomputing L2-norms of word weight vectors
#     1. 0.47 'attests'
#     2. 0.45 'Beach,"'
#     3. 0.42 'parody?'
#     4. 0.42 'unite'
#     5. 0.41 'Jansen,'
#     6. 0.41 '(wonderful!)'
#     7. 0.41 'scamming'
#     8. 0.40 "Talia's"
#     9. 0.40 'Aeris'
#     10. 0.40 'Russo),'
#
# target_word: '(Ron' model: Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t4) similar words:
# 2019-11-21 18:20:42,411 : INFO : precomputing L2-norms of word weight vectors
#     1. 0.55 'Smith),'
#     2. 0.54 'Ford),'
#     3. 0.51 '(Gordon'
#     4. 0.51 'Poe.<br'
#     5. 0.50 '(Humphrey'
#     6. 0.50 '(Willie'
#     7. 0.50 'Boone,'
#     8. 0.50 'Stein,'
#     9. 0.49 'Osborne,'
#     10. 0.49 'Curtis)'
#
# target_word: '(Ron' model: Doc2Vec(dm/c,d100,n5,w5,mc2,t4) similar words:
#     1. 0.67 '(Timothy'
#     2. 0.66 '(Gary'
#     3. 0.66 '(Ben'
#     4. 0.63 '(Linda'
#     5. 0.63 '(Morgan'
#     6. 0.63 '(Edward'
#     7. 0.63 '(Jack'
#     8. 0.63 'Hobbes,'
#     9. 0.63 '(Christopher'
#     10. 0.62 '(Isabelle'

# %% [markdown]
# Do the DBOW words look meaningless? That's because the gensim DBOW model
# doesn't train word vectors – they remain at their random initialized values –
# unless you ask with the ``dbow_words=1`` initialization parameter. Concurrent
# word-training slows DBOW mode significantly, and offers little improvement
# (and sometimes a little worsening) of the error rate on this IMDB
# sentiment-prediction task, but may be appropriate on other tasks, or if you
# also need word-vectors.
#
# Words from DM models tend to show meaningfully similar words when there are
# many examples in the training data (as with 'plot' or 'actor'). (All DM modes
# inherently involve word-vector training concurrent with doc-vector training.)

# %% [markdown]
# Are the word vectors from this dataset any good at analogies?
# -------------------------------------------------------------

# %%
# grab the file if not already local
questions_filename = 'questions-words.txt'
if not os.path.isfile(questions_filename):
    # Download IMDB archive
    print("Downloading analogy questions file...")
    url = u'https://raw.githubusercontent.com/tmikolov/word2vec/master/questions-words.txt'
    with smart_open.open(url, 'rb') as fin:
        with smart_open.open(questions_filename, 'wb') as fout:
            fout.write(fin.read())
assert os.path.isfile(questions_filename), "questions-words.txt unavailable"
print("Success, questions-words.txt is available for next steps.")

# Note: this analysis takes many minutes
for model in word_models:
    score, sections = model.wv.evaluate_word_analogies('questions-words.txt')
    correct, incorrect = len(sections[-1]['correct']), len(sections[-1]['incorrect'])
    print('%s: %0.2f%% correct (%d of %d)' % (model, float(correct*100)/(correct+incorrect), correct, correct+incorrect))
# Out:
# Downloading analogy questions file...
# Success, questions-words.txt is available for next steps.
# 2019-11-21 18:21:09,211 : INFO : Evaluating word analogies for top 300000 words in the model on questions-words.txt
# 2019-11-21 18:21:15,694 : INFO : capital-common-countries: 0.0% (0/420)
# 2019-11-21 18:21:26,841 : INFO : capital-world: 0.0% (0/902)
# 2019-11-21 18:21:27,792 : INFO : currency: 0.0% (0/86)
# 2019-11-21 18:21:45,032 : INFO : city-in-state: 0.0% (0/1510)
# 2019-11-21 18:21:51,400 : INFO : family: 0.0% (0/506)
# 2019-11-21 18:22:02,292 : INFO : gram1-adjective-to-adverb: 0.0% (0/992)
# 2019-11-21 18:22:10,881 : INFO : gram2-opposite: 0.0% (0/756)
# 2019-11-21 18:22:25,265 : INFO : gram3-comparative: 0.0% (0/1332)
# 2019-11-21 18:22:36,619 : INFO : gram4-superlative: 0.0% (0/1056)
# 2019-11-21 18:22:47,368 : INFO : gram5-present-participle: 0.0% (0/992)
# 2019-11-21 18:23:02,669 : INFO : gram6-nationality-adjective: 0.0% (0/1445)
# 2019-11-21 18:23:19,227 : INFO : gram7-past-tense: 0.0% (0/1560)
# 2019-11-21 18:23:31,653 : INFO : gram8-plural: 0.0% (0/1190)
# 2019-11-21 18:23:41,259 : INFO : gram9-plural-verbs: 0.0% (0/870)
# 2019-11-21 18:23:41,261 : INFO : Quadruplets with out-of-vocabulary words: 30.3%
# 2019-11-21 18:23:41,263 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-11-21 18:23:41,265 : INFO : Total accuracy: 0.0% (0/13617)
# Doc2Vec(dbow,d100,n5,mc2,t4): 0.00% correct (0 of 13617)
# 2019-11-21 18:23:42,263 : INFO : Evaluating word analogies for top 300000 words in the model on questions-words.txt
# 2019-11-21 18:23:46,695 : INFO : capital-common-countries: 3.3% (14/420)
# 2019-11-21 18:23:57,115 : INFO : capital-world: 0.4% (4/902)
# 2019-11-21 18:23:58,037 : INFO : currency: 0.0% (0/86)
# 2019-11-21 18:24:14,259 : INFO : city-in-state: 0.1% (2/1510)
# 2019-11-21 18:24:20,041 : INFO : family: 37.2% (188/506)
# 2019-11-21 18:24:31,152 : INFO : gram1-adjective-to-adverb: 2.8% (28/992)
# 2019-11-21 18:24:39,537 : INFO : gram2-opposite: 5.6% (42/756)
# 2019-11-21 18:24:56,137 : INFO : gram3-comparative: 49.2% (656/1332)
# 2019-11-21 18:25:08,873 : INFO : gram4-superlative: 24.5% (259/1056)
# 2019-11-21 18:25:21,103 : INFO : gram5-present-participle: 23.3% (231/992)
# 2019-11-21 18:25:38,774 : INFO : gram6-nationality-adjective: 2.4% (35/1445)
# 2019-11-21 18:25:59,006 : INFO : gram7-past-tense: 28.1% (438/1560)
# 2019-11-21 18:26:12,183 : INFO : gram8-plural: 16.9% (201/1190)
# 2019-11-21 18:26:22,909 : INFO : gram9-plural-verbs: 43.0% (374/870)
# 2019-11-21 18:26:22,911 : INFO : Quadruplets with out-of-vocabulary words: 30.3%
# 2019-11-21 18:26:22,912 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-11-21 18:26:22,913 : INFO : Total accuracy: 18.2% (2472/13617)
# Doc2Vec("alpha=0.05",dm/m,d100,n5,w10,mc2,t4): 18.15% correct (2472 of 13617)
# 2019-11-21 18:26:24,098 : INFO : Evaluating word analogies for top 300000 words in the model on questions-words.txt
# 2019-11-21 18:26:29,037 : INFO : capital-common-countries: 2.4% (10/420)
# 2019-11-21 18:26:38,397 : INFO : capital-world: 0.3% (3/902)
# 2019-11-21 18:26:39,348 : INFO : currency: 0.0% (0/86)
# 2019-11-21 18:26:55,112 : INFO : city-in-state: 0.3% (5/1510)
# 2019-11-21 18:27:00,694 : INFO : family: 37.4% (189/506)
# 2019-11-21 18:27:11,203 : INFO : gram1-adjective-to-adverb: 7.4% (73/992)
# 2019-11-21 18:27:19,545 : INFO : gram2-opposite: 3.7% (28/756)
# 2019-11-21 18:27:34,592 : INFO : gram3-comparative: 36.5% (486/1332)
# 2019-11-21 18:27:46,404 : INFO : gram4-superlative: 28.0% (296/1056)
# 2019-11-21 18:27:57,470 : INFO : gram5-present-participle: 34.4% (341/992)
# 2019-11-21 18:28:14,761 : INFO : gram6-nationality-adjective: 2.0% (29/1445)
# 2019-11-21 18:28:32,915 : INFO : gram7-past-tense: 26.0% (406/1560)
# 2019-11-21 18:28:47,032 : INFO : gram8-plural: 9.4% (112/1190)
# 2019-11-21 18:28:56,448 : INFO : gram9-plural-verbs: 49.5% (431/870)
# 2019-11-21 18:28:56,451 : INFO : Quadruplets with out-of-vocabulary words: 30.3%
# 2019-11-21 18:28:56,453 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2019-11-21 18:28:56,454 : INFO : Total accuracy: 17.7% (2409/13617)
# Doc2Vec(dm/c,d100,n5,w5,mc2,t4): 17.69% correct (2409 of 13617)

# %% [markdown]
# Even though this is a tiny, domain-specific dataset, it shows some meager
# capability on the general word analogies – at least for the DM/mean and
# DM/concat models which actually train word vectors. (The untrained
# random-initialized words of the DBOW model of course fail miserably.)
